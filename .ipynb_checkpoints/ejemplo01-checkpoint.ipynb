# %%
import pandas as pd

# %%
# !pip install faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.9 MB/s eta 0:00:003.8 MB/s eta 0:00:01
# ...

# %%
from faker import Faker
fake = Faker()

# %%
diccionario = {'nombre':fake,name()}

# %%
lista = []

# %%
for x in range(0,51):
    lista.append({'nombre': fake.name()})

# %%
lista
# Out:
# [{'nombre': 'Ryan Johnson'},
#  {'nombre': 'Jaime Hubbard'},
#  {'nombre': 'Robert Powell PhD'},
#  {'nombre': 'Deborah Castaneda'},
#  {'nombre': 'Kristy Gonzalez'},
#  {'nombre': 'Angela Evans'},
#  {'nombre': 'Sheryl Bradley'},
#  {'nombre': 'Bianca Cummings'},
#  {'nombre': 'Sandra Thompson'},
#  {'nombre': 'Marie Callahan'},
#  {'nombre': 'Ashley Alvarez'},
#  {'nombre': 'Kevin Davis'},
#  {'nombre': 'Victoria Baker'},
#  {'nombre': 'Terri Cabrera'},
#  {'nombre': 'Amanda Hernandez'},
#  {'nombre': 'William Sanchez'},
#  {'nombre': 'Cynthia Brown'},
#  {'nombre': 'Colleen Clark'},
#  {'nombre': 'Ashley Murray'},
#  {'nombre': 'Lauren Shaffer'},
#  {'nombre': 'Michael Rogers'},
#  {'nombre': 'Carol Rivera'},
#  {'nombre': 'Matthew Wilson MD'},
#  {'nombre': 'John Ashley'},
#  {'nombre': 'Victoria Johnson'},
#  {'nombre': 'Mary Zavala'},
#  {'nombre': 'Matthew Dougherty'},
#  {'nombre': 'Michael Hayes'},
#  {'nombre': 'Alison Diaz DDS'},
#  {'nombre': 'John Brown'},
# ...

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                nombre
# 0        Ryan Johnson
# 1       Jaime Hubbard
# 2   Robert Powell PhD
# 3   Deborah Castaneda
# 4     Kristy Gonzalez
# 5        Angela Evans
# 6      Sheryl Bradley
# 7     Bianca Cummings
# 8     Sandra Thompson
# 9      Marie Callahan
# 10     Ashley Alvarez
# 11        Kevin Davis
# 12     Victoria Baker
# 13      Terri Cabrera
# 14   Amanda Hernandez
# 15    William Sanchez
# 16      Cynthia Brown
# 17      Colleen Clark
# 18      Ashley Murray
# 19     Lauren Shaffer
# 20     Michael Rogers
# 21       Carol Rivera
# 22  Matthew Wilson MD
# 23        John Ashley
# 24   Victoria Johnson
# 25        Mary Zavala
# 26  Matthew Dougherty
# 27      Michael Hayes
# 28    Alison Diaz DDS
# 29         John Brown
# 30       Holly Harmon
# 31    Allison Compton
# 32     Diana Benjamin
# 33    Danielle Newman
# 34    Melissa Pacheco
# 35       Susan Daniel
# 36  Christine Elliott
# 37     Brenda Huffman
# 38      Anthony Jones
# 39      April Cabrera
# ...

# %%
data.to_csv("misdata.csv", index=False)
